# %% [markdown]
# #### Algerian Forest Fires Dataset Project EDA Part:
# 1. UNDERSTANDING THE GIVEN TASK:
# Solve in ipynb:
# Import the dataset. https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++#
# Do proper EDA(analysis) of your dataset and create a report
# Then perform necessary preprocessing steps
# 2. DATA COLLECTION AND UNDERSTANDING
# I used a dataset on Algerian Forest Fires from UCI. The dataset contains a culmination of forest fire observations and data in two regions of Algeria: the Bejaia region and the Sidi Bel-Abbes region. The timeline of this dataset is from June 2012 to September 2012. In this project, we focused on whether certain weather features could predict forest fires in these regions using few Classification algorithms.
# As per the Task given i choose regression problem to predict fire weather index
# 3. DATA EXPLORATION
# In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn. It is always a good practice to understand the data first and try to gather as many insights from it.
# Below are tasks to be performed in EDA:
#
# 1. Importing Libraries
#
# 2. Data Cleaning for EDA Report
#
# 3. Exploratory Data Analysis (EDA) on all Features

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
dataset=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
dataset
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# 2    0.1   not fire
# 3      0   not fire
# 4    0.5   not fire
# ..   ...           ...
# 241  6.5       fire
# 242    0   not fire
# 243  0.2   not fire
# 244  0.7   not fire
# 245  0.5  not fire
#
# [246 rows x 14 columns]

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
# convert Dataframe into dictionary as MongoDB stores in records/documents

data=dataset.to_dict(orient='records')   #Convert the DataFrame to a dictionary.
                                         # when the orient=records it means that the resulting dictionary will be a list where each element in the list represents a record in the dataframe

# %%
data
# Out:
# [{'day': '01',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '57',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '65.7',
#   'DMC': '3.4',
#   'DC': '7.6',
#   'ISI': '1.3',
#   'BUI': '3.4',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '61',
#   ' Ws': '13',
#   'Rain ': '1.3',
#   'FFMC': '64.4',
#   'DMC': '4.1',
#   'DC': '7.6',
#   'ISI': '1',
#   'BUI': '3.9',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '03',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '26',
#   ' RH': '82',
#   ' Ws': '22',
#   'Rain ': '13.1',
#   'FFMC': '47.1',
#   'DMC': '2.5',
#   'DC': '7.1',
#   'ISI': '0.3',
#   'BUI': '2.7',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '04',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '89',
#   ' Ws': '13',
#   'Rain ': '2.5',
#   'FFMC': '28.6',
#   'DMC': '1.3',
#   'DC': '6.9',
#   'ISI': '0',
#   'BUI': '1.7',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '05',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '77',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '64.8',
#   'DMC': '3',
#   'DC': '14.2',
#   'ISI': '1.2',
#   'BUI': '3.9',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '06',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '67',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '82.6',
#   'DMC': '5.8',
#   'DC': '22.2',
#   'ISI': '3.1',
#   'BUI': '7',
#   'FWI': '2.5',
#   'Classes  ': 'fire   '},
#  {'day': '07',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '54',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '88.2',
#   'DMC': '9.9',
#   'DC': '30.5',
#   'ISI': '6.4',
#   'BUI': '10.9',
#   'FWI': '7.2',
#   'Classes  ': 'fire   '},
#  {'day': '08',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '73',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86.6',
#   'DMC': '12.1',
#   'DC': '38.3',
#   'ISI': '5.6',
#   'BUI': '13.5',
#   'FWI': '7.1',
#   'Classes  ': 'fire   '},
#  {'day': '09',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '88',
#   ' Ws': '13',
#   'Rain ': '0.2',
#   'FFMC': '52.9',
#   'DMC': '7.9',
#   'DC': '38.8',
#   'ISI': '0.4',
#   'BUI': '10.5',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '10',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '79',
#   ' Ws': '12',
#   'Rain ': '0',
#   'FFMC': '73.2',
#   'DMC': '9.5',
#   'DC': '46.3',
#   'ISI': '1.3',
#   'BUI': '12.6',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '11',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '65',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '84.5',
#   'DMC': '12.5',
#   'DC': '54.3',
#   'ISI': '4',
#   'BUI': '15.8',
#   'FWI': '5.6',
#   'Classes  ': 'fire   '},
#  {'day': '12',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '26',
#   ' RH': '81',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '84',
#   'DMC': '13.8',
#   'DC': '61.4',
#   'ISI': '4.8',
#   'BUI': '17.7',
#   'FWI': '7.1 ',
#   'Classes  ': 'fire   '},
#  {'day': '13',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '84',
#   ' Ws': '21',
#   'Rain ': '1.2',
#   'FFMC': '50',
#   'DMC': '6.7',
#   'DC': '17',
#   'ISI': '0.5',
#   'BUI': '6.7',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '14',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '78',
#   ' Ws': '20',
#   'Rain ': '0.5',
#   'FFMC': '59',
#   'DMC': '4.6',
#   'DC': '7.8',
#   'ISI': '1',
#   'BUI': '4.4',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '15',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '80',
#   ' Ws': '17',
#   'Rain ': '3.1',
#   'FFMC': '49.4',
#   'DMC': '3',
#   'DC': '7.4',
#   'ISI': '0.4',
#   'BUI': '3',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '16',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '89',
#   ' Ws': '13',
#   'Rain ': '0.7',
#   'FFMC': '36.1',
#   'DMC': '1.7',
#   'DC': '7.6',
#   'ISI': '0',
#   'BUI': '2.2',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '17',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '89',
#   ' Ws': '16',
#   'Rain ': '0.6',
#   'FFMC': '37.3',
#   'DMC': '1.1',
#   'DC': '7.8',
#   'ISI': '0',
#   'BUI': '1.6',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '18',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '78',
#   ' Ws': '14',
#   'Rain ': '0.3',
#   'FFMC': '56.9',
#   'DMC': '1.9',
#   'DC': '8',
#   'ISI': '0.7',
#   'BUI': '2.4',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '19',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '55',
#   ' Ws': '16',
#   'Rain ': '0.1',
#   'FFMC': '79.9',
#   'DMC': '4.5',
#   'DC': '16',
#   'ISI': '2.5',
#   'BUI': '5.3',
#   'FWI': '1.4',
#   'Classes  ': 'not fire   '},
#  {'day': '20',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '80',
#   ' Ws': '16',
#   'Rain ': '0.4',
#   'FFMC': '59.8',
#   'DMC': '3.4',
#   'DC': '27.1',
#   'ISI': '0.9',
#   'BUI': '5.1',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '21',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '78',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '81',
#   'DMC': '6.3',
#   'DC': '31.6',
#   'ISI': '2.6',
#   'BUI': '8.4',
#   'FWI': '2.2',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '67',
#   ' Ws': '17',
#   'Rain ': '0.1',
#   'FFMC': '79.1',
#   'DMC': '7',
#   'DC': '39.5',
#   'ISI': '2.4',
#   'BUI': '9.7',
#   'FWI': '2.3',
#   'Classes  ': 'not fire   '},
#  {'day': '23',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '62',
#   ' Ws': '18',
#   'Rain ': '0.1',
#   'FFMC': '81.4',
#   'DMC': '8.2',
#   'DC': '47.7',
#   'ISI': '3.3',
#   'BUI': '11.5',
#   'FWI': '3.8',
#   'Classes  ': 'fire   '},
#  {'day': '24',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '66',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '85.9',
#   'DMC': '11.2',
#   'DC': '55.8',
#   'ISI': '5.6',
#   'BUI': '14.9',
#   'FWI': '7.5',
#   'Classes  ': 'fire   '},
#  {'day': '25',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '64',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86.7',
#   'DMC': '14.2',
#   'DC': '63.8',
#   'ISI': '5.7',
#   'BUI': '18.3',
#   'FWI': '8.4',
#   'Classes  ': 'fire   '},
#  {'day': '26',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '64',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '86.8',
#   'DMC': '17.8',
#   'DC': '71.8',
#   'ISI': '6.7',
#   'BUI': '21.6',
#   'FWI': '10.6',
#   'Classes  ': 'fire   '},
#  {'day': '27',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '53',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '89',
#   'DMC': '21.6',
#   'DC': '80.3',
#   'ISI': '9.2',
#   'BUI': '25.8',
#   'FWI': '15',
#   'Classes  ': 'fire   '},
#  {'day': '28',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '55',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '89.1',
#   'DMC': '25.5',
#   'DC': '88.5',
#   'ISI': '7.6',
#   'BUI': '29.7',
#   'FWI': '13.9',
#   'Classes  ': 'fire   '},
#  {'day': '29',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '47',
#   ' Ws': '13',
#   'Rain ': '0.3',
#   'FFMC': '79.9',
#   'DMC': '18.4',
#   'DC': '84.4',
#   'ISI': '2.2',
#   'BUI': '23.8',
#   'FWI': '3.9',
#   'Classes  ': 'not fire   '},
#  {'day': '30',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '50',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '88.7',
#   'DMC': '22.9',
#   'DC': '92.8',
#   'ISI': '7.2',
#   'BUI': '28.3',
#   'FWI': '12.9',
#   'Classes  ': 'fire   '},
#  {'day': '01',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '68',
#   ' Ws': '19',
#   'Rain ': '1',
#   'FFMC': '59.9',
#   'DMC': '2.5',
#   'DC': '8.6',
#   'ISI': '1.1',
#   'BUI': '2.9',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '75',
#   ' Ws': '19',
#   'Rain ': '1.2',
#   'FFMC': '55.7',
#   'DMC': '2.4',
#   'DC': '8.3',
#   'ISI': '0.8',
#   'BUI': '2.8',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '03',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '76',
#   ' Ws': '20',
#   'Rain ': '0.7',
#   'FFMC': '63.1',
#   'DMC': '2.6',
#   'DC': '9.2',
#   'ISI': '1.3',
#   'BUI': '3',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '04',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '78',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '80.1',
#   'DMC': '4.6',
#   'DC': '18.5',
#   'ISI': '2.7',
#   'BUI': '5.7',
#   'FWI': '1.7',
#   'Classes  ': 'not fire   '},
#  {'day': '05',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '66',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '85.9',
#   'DMC': '7.6',
#   'DC': '27.9',
#   'ISI': '4.8',
#   'BUI': '9.1',
#   'FWI': '4.9',
#   'Classes  ': 'fire   '},
#  {'day': '06',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '63',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '87',
#   'DMC': '10.9',
#   'DC': '37',
#   'ISI': '5.6',
#   'BUI': '12.5',
#   'FWI': '6.8',
#   'Classes  ': 'fire   '},
#  {'day': '07',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '64',
#   ' Ws': '18',
#   'Rain ': '0.2',
#   'FFMC': '80',
#   'DMC': '9.7',
#   'DC': '40.4',
#   'ISI': '2.8',
#   'BUI': '12.1',
#   'FWI': '3.2',
#   'Classes  ': 'not fire   '},
#  {'day': '08',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '68',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '85.6',
#   'DMC': '12.5',
#   'DC': '49.8',
#   'ISI': '6',
#   'BUI': '15.4',
#   'FWI': '8',
#   'Classes  ': 'fire   '},
#  {'day': '09',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '68',
#   ' Ws': '14',
#   'Rain ': '1.4',
#   'FFMC': '66.6',
#   'DMC': '7.7',
#   'DC': '9.2',
#   'ISI': '1.1',
#   'BUI': '7.4',
#   'FWI': '0.6',
#   'Classes  ': 'not fire   '},
#  {'day': '10',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '69',
#   ' Ws': '13',
#   'Rain ': '0.7',
#   'FFMC': '66.6',
#   'DMC': '6',
#   'DC': '9.3',
#   'ISI': '1.1',
#   'BUI': '5.8',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '11',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '76',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '81.1',
#   'DMC': '8.1',
#   'DC': '18.7',
#   'ISI': '2.6',
#   'BUI': '8.1',
#   'FWI': '2.2',
#   'Classes  ': 'not fire   '},
#  {'day': '12',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '75',
#   ' Ws': '13',
#   'Rain ': '0.1',
#   'FFMC': '75.1',
#   'DMC': '7.9',
#   'DC': '27.7',
#   'ISI': '1.5',
#   'BUI': '9.2',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '13',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '81',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '81.8',
#   'DMC': '9.7',
#   'DC': '37.2',
#   'ISI': '3',
#   'BUI': '11.7',
#   'FWI': '3.4',
#   'Classes  ': 'not fire   '},
#  {'day': '14',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '61',
#   ' Ws': '13',
#   'Rain ': '0.6',
#   'FFMC': '73.9',
#   'DMC': '7.8',
#   'DC': '22.9',
#   'ISI': '1.4',
#   'BUI': '8.4',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '15',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '80',
#   ' Ws': '19',
#   'Rain ': '0.4',
#   'FFMC': '60.7',
#   'DMC': '5.2',
#   'DC': '17',
#   'ISI': '1.1',
#   'BUI': '5.9',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '16',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '76',
#   ' Ws': '21',
#   'Rain ': '0',
#   'FFMC': '72.6',
#   'DMC': '7',
#   'DC': '25.5',
#   'ISI': '0.7',
#   'BUI': '8.3',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '17',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '70',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '82.8',
#   'DMC': '9.4',
#   'DC': '34.1',
#   'ISI': '3.2',
#   'BUI': '11.1',
#   'FWI': '3.6',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '68',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '85.4',
#   'DMC': '12.1',
#   'DC': '43.1',
#   'ISI': '4.6',
#   'BUI': '14.2',
#   'FWI': '6',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '59',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '88.1',
#   'DMC': '12',
#   'DC': '52.8',
#   'ISI': '7.7',
#   'BUI': '18.2',
#   'FWI': '10.9',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '65',
#   ' Ws': '15',
#   'Rain ': '0.1',
#   'FFMC': '81.4',
#   'DMC': '12.3',
#   'DC': '62.1',
#   'ISI': '2.8',
#   'BUI': '16.5',
#   'FWI': '4',
#   'Classes  ': 'fire   '},
#  {'day': '21',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '70',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '85.4',
#   'DMC': '18.5',
#   'DC': '71.5',
#   'ISI': '5.2',
#   'BUI': '22.4',
#   'FWI': '8.8',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '79',
#   ' Ws': '18',
#   'Rain ': '0.1',
#   'FFMC': '73.4',
#   'DMC': '16.4',
#   'DC': '79.9',
#   'ISI': '1.8',
#   'BUI': '21.7',
#   'FWI': '2.8',
#   'Classes  ': 'not fire   '},
#  {'day': '23',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '66',
#   ' Ws': '22',
#   'Rain ': '0.4',
#   'FFMC': '68.2',
#   'DMC': '10.5',
#   'DC': '71.3',
#   'ISI': '1.8',
#   'BUI': '15.4',
#   'FWI': '2.1',
#   'Classes  ': 'not fire   '},
#  {'day': '24',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '78',
#   ' Ws': '16',
#   'Rain ': '0.1',
#   'FFMC': '70',
#   'DMC': '9.6',
#   'DC': '79.7',
#   'ISI': '1.4',
#   'BUI': '14.7',
#   'FWI': '1.3',
#   'Classes  ': 'not fire   '},
#  {'day': '25',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '65',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '84.3',
#   'DMC': '12.5',
#   'DC': '88.7',
#   'ISI': '4.8',
#   'BUI': '18.5',
#   'FWI': '7.3',
#   'Classes  ': 'fire   '},
#  {'day': '26',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '53',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '89.2',
#   'DMC': '17.1',
#   'DC': '98.6',
#   'ISI': '10',
#   'BUI': '23.9',
#   'FWI': '15.3',
#   'Classes  ': 'fire   '},
#  {'day': '27',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '48',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '90.3',
#   'DMC': '22.2',
#   'DC': '108.5',
#   'ISI': '8.7',
#   'BUI': '29.4',
#   'FWI': '15.3',
#   'Classes  ': 'fire   '},
#  {'day': '28',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '76',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86.5',
#   'DMC': '24.4',
#   'DC': '117.8',
#   'ISI': '5.6',
#   'BUI': '32.1',
#   'FWI': '11.3',
#   'Classes  ': 'fire   '},
#  {'day': '29',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '73',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86.6',
#   'DMC': '26.7',
#   'DC': '127',
#   'ISI': '5.6',
#   'BUI': '35',
#   'FWI': '11.9',
#   'Classes  ': 'fire   '},
#  {'day': '30',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '79',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '85.4',
#   'DMC': '28.5',
#   'DC': '136',
#   'ISI': '4.7',
#   'BUI': '37.4',
#   'FWI': '10.7',
#   'Classes  ': 'fire   '},
#  {'day': '31',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '64',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '87.2',
#   'DMC': '31.9',
#   'DC': '145.7',
#   'ISI': '6.8',
#   'BUI': '41.2',
#   'FWI': '15.7',
#   'Classes  ': 'fire   '},
#  {'day': '01',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '45',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '78.8',
#   'DMC': '4.8',
#   'DC': '10.2',
#   'ISI': '2',
#   'BUI': '4.7',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '55',
#   ' Ws': '12',
#   'Rain ': '0.4',
#   'FFMC': '78',
#   'DMC': '5.8',
#   'DC': '10',
#   'ISI': '1.7',
#   'BUI': '5.5',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '03',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '63',
#   ' Ws': '14',
#   'Rain ': '0.3',
#   'FFMC': '76.6',
#   'DMC': '5.7',
#   'DC': '10',
#   'ISI': '1.7',
#   'BUI': '5.5',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '04',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '69',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '85',
#   'DMC': '8.2',
#   'DC': '19.8',
#   'ISI': '4',
#   'BUI': '8.2',
#   'FWI': '3.9',
#   'Classes  ': 'fire   '},
#  {'day': '05',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '65',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '86.8',
#   'DMC': '11.1',
#   'DC': '29.7',
#   'ISI': '5.2',
#   'BUI': '11.5',
#   'FWI': '6.1',
#   'Classes  ': 'fire   '},
#  {'day': '06',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '75',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '86.4',
#   'DMC': '13',
#   'DC': '39.1',
#   'ISI': '5.2',
#   'BUI': '14.2',
#   'FWI': '6.8',
#   'Classes  ': 'fire   '},
#  {'day': '07',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '69',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '86.5',
#   'DMC': '15.5',
#   'DC': '48.6',
#   'ISI': '5.5',
#   'BUI': '17.2',
#   'FWI': '8',
#   'Classes  ': 'fire   '},
#  {'day': '08',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '60',
#   ' Ws': '18',
#   'Rain ': '0.3',
#   'FFMC': '77.1',
#   'DMC': '11.3',
#   'DC': '47',
#   'ISI': '2.2',
#   'BUI': '14.1',
#   'FWI': '2.6',
#   'Classes  ': 'not fire   '},
#  {'day': '09',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '59',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '87.4',
#   'DMC': '14.8',
#   'DC': '57',
#   'ISI': '6.9',
#   'BUI': '17.9',
#   'FWI': '9.9',
#   'Classes  ': 'fire   '},
#  {'day': '10',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '55',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '18.6',
#   'DC': '67',
#   'ISI': '7.4',
#   'BUI': '21.9',
#   'FWI': '11.6',
#   'Classes  ': 'fire   '},
#  {'day': '11',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '63',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '21.7',
#   'DC': '77',
#   'ISI': '7.1',
#   'BUI': '25.5',
#   'FWI': '12.1',
#   'Classes  ': 'fire   '},
#  {'day': '12',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '51',
#   ' Ws': '13',
#   'Rain ': '0.3',
#   'FFMC': '81.3',
#   'DMC': '15.6',
#   'DC': '75.1',
#   'ISI': '2.5',
#   'BUI': '20.7',
#   'FWI': '4.2',
#   'Classes  ': 'not fire   '},
#  {'day': '13',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '63',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '87',
#   'DMC': '19',
#   'DC': '85.1',
#   'ISI': '5.9',
#   'BUI': '24.4',
#   'FWI': '10.2',
#   'Classes  ': 'fire   '},
#  {'day': '14',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '66',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '87',
#   'DMC': '21.7',
#   'DC': '94.7',
#   'ISI': '5.7',
#   'BUI': '27.2',
#   'FWI': '10.6',
#   'Classes  ': 'fire   '},
#  {'day': '15',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '55',
#   ' Ws': '13',
#   'Rain ': '0.3',
#   'FFMC': '82.4',
#   'DMC': '15.6',
#   'DC': '92.5',
#   'ISI': '3.7',
#   'BUI': '22',
#   'FWI': '6.3',
#   'Classes  ': 'fire   '},
#  {'day': '16',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '61',
#   ' Ws': '18',
#   'Rain ': '0.3',
#   'FFMC': '80.2',
#   'DMC': '11.7',
#   'DC': '90.4',
#   'ISI': '2.8',
#   'BUI': '17.6',
#   'FWI': '4.2',
#   'Classes  ': 'fire   '},
#  {'day': '17',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '52',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '89.3',
#   'DMC': '16',
#   'DC': '100.7',
#   'ISI': '9.7',
#   'BUI': '22.9',
#   'FWI': '14.6',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '54',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '89.4',
#   'DMC': '20',
#   'DC': '110.9',
#   'ISI': '9.7',
#   'BUI': '27.5',
#   'FWI': '16.1',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '62',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '89.4',
#   'DMC': '23.2',
#   'DC': '120.9',
#   'ISI': '9.7',
#   'BUI': '31.3',
#   'FWI': '17.2',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '68',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '88.3',
#   'DMC': '25.9',
#   'DC': '130.6',
#   'ISI': '8.8',
#   'BUI': '34.7',
#   'FWI': '16.8',
#   'Classes  ': 'fire   '},
#  {'day': '21',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '58',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '88.6',
#   'DMC': '29.6',
#   'DC': '141.1',
#   'ISI': '9.2',
#   'BUI': '38.8',
#   'FWI': '18.4',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '55',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '89.1',
#   'DMC': '33.5',
#   'DC': '151.3',
#   'ISI': '9.9',
#   'BUI': '43.1',
#   'FWI': '20.4',
#   'Classes  ': 'fire   '},
#  {'day': '23',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '53',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '89.5',
#   'DMC': '37.6',
#   'DC': '161.5',
#   'ISI': '10.4',
#   'BUI': '47.5',
#   'FWI': '22.3',
#   'Classes  ': 'fire'},
#  {'day': '24',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '64',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '40.5',
#   'DC': '171.3',
#   'ISI': '9',
#   'BUI': '50.9',
#   'FWI': '20.9',
#   'Classes  ': 'fire   '},
#  {'day': '25',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '60',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '43.9',
#   'DC': '181.3',
#   'ISI': '8.2',
#   'BUI': '54.7',
#   'FWI': '20.3',
#   'Classes  ': 'fire'},
#  {'day': '26',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '78',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '85.8',
#   'DMC': '45.6',
#   'DC': '190.6',
#   'ISI': '4.7',
#   'BUI': '57.1',
#   'FWI': '13.7',
#   'Classes  ': 'fire '},
#  {'day': '27',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '82',
#   ' Ws': '21',
#   'Rain ': '0',
#   'FFMC': '84.9',
#   'DMC': '47',
#   'DC': '200.2',
#   'ISI': '4.4',
#   'BUI': '59.3',
#   'FWI': '13.2',
#   'Classes  ': 'fire'},
#  {'day': '28',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '64',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '89.4',
#   'DMC': '50.2',
#   'DC': '210.4',
#   'ISI': '7.3',
#   'BUI': '62.9',
#   'FWI': '19.9',
#   'Classes  ': 'fire '},
#  {'day': '29',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '48',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '90.1',
#   'DMC': '54.2',
#   'DC': '220.4',
#   'ISI': '12.5',
#   'BUI': '67.4',
#   'FWI': '30.2',
#   'Classes  ': 'fire   '},
#  {'day': '30',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '70',
#   ' Ws': '17',
#   'Rain ': '0.8',
#   'FFMC': '72.7',
#   'DMC': '25.2',
#   'DC': '180.4',
#   'ISI': '1.7',
#   'BUI': '37.4',
#   'FWI': '4.2',
#   'Classes  ': 'not fire   '},
#  {'day': '31',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '80',
#   ' Ws': '21',
#   'Rain ': '16.8',
#   'FFMC': '52.5',
#   'DMC': '8.7',
#   'DC': '8.7',
#   'ISI': '0.6',
#   'BUI': '8.3',
#   'FWI': '0.3',
#   'Classes  ': 'not fire'},
#  {'day': '01',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '76',
#   ' Ws': '17',
#   'Rain ': '7.2',
#   'FFMC': '46',
#   'DMC': '1.3',
#   'DC': '7.5',
#   'ISI': '0.2',
#   'BUI': '1.8',
#   'FWI': '0.1',
#   'Classes  ': 'not fire '},
#  {'day': '02',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '22',
#   ' RH': '86',
#   ' Ws': '15',
#   'Rain ': '10.1',
#   'FFMC': '30.5',
#   'DMC': '0.7',
#   'DC': '7',
#   'ISI': '0',
#   'BUI': '1.1',
#   'FWI': '0',
#   'Classes  ': 'not fire'},
#  {'day': '03',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '78',
#   ' Ws': '15',
#   'Rain ': '3.8',
#   'FFMC': '42.6',
#   'DMC': '1.2',
#   'DC': '7.5',
#   'ISI': '0.1',
#   'BUI': '1.7',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '04',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '73',
#   ' Ws': '17',
#   'Rain ': '0.1',
#   'FFMC': '68.4',
#   'DMC': '1.9',
#   'DC': '15.7',
#   'ISI': '1.4',
#   'BUI': '2.9',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '05',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '75',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '80.8',
#   'DMC': '3.4',
#   'DC': '24',
#   'ISI': '2.8',
#   'BUI': '5.1',
#   'FWI': '1.7',
#   'Classes  ': 'fire   '},
#  {'day': '06',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '74',
#   ' Ws': '19',
#   'Rain ': '0.1',
#   'FFMC': '75.8',
#   'DMC': '3.6',
#   'DC': '32.2',
#   'ISI': '2.1',
#   'BUI': '5.6',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '07',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '71',
#   ' Ws': '17',
#   'Rain ': '0.3',
#   'FFMC': '69.6',
#   'DMC': '3.2',
#   'DC': '30.1',
#   'ISI': '1.5',
#   'BUI': '5.1',
#   'FWI': '0.6',
#   'Classes  ': 'not fire   '},
#  {'day': '08',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '73',
#   ' Ws': '17',
#   'Rain ': '0.9',
#   'FFMC': '62',
#   'DMC': '2.6',
#   'DC': '8.4',
#   'ISI': '1.1',
#   'BUI': '3',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '09',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '77',
#   ' Ws': '15',
#   'Rain ': '1',
#   'FFMC': '56.1',
#   'DMC': '2.1',
#   'DC': '8.4',
#   'ISI': '0.7',
#   'BUI': '2.6',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '10',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '73',
#   ' Ws': '12',
#   'Rain ': '1.8',
#   'FFMC': '59.9',
#   'DMC': '2.2',
#   'DC': '8.9',
#   'ISI': '0.7',
#   'BUI': '2.7',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '11',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '77',
#   ' Ws': '21',
#   'Rain ': '1.8',
#   'FFMC': '58.5',
#   'DMC': '1.9',
#   'DC': '8.4',
#   'ISI': '1.1',
#   'BUI': '2.4',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '12',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '88',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '71',
#   'DMC': '2.6',
#   'DC': '16.6',
#   'ISI': '1.2',
#   'BUI': '3.7',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '13',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '86',
#   ' Ws': '21',
#   'Rain ': '4.6',
#   'FFMC': '40.9',
#   'DMC': '1.3',
#   'DC': '7.5',
#   'ISI': '0.1',
#   'BUI': '1.8',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '14',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '22',
#   ' RH': '76',
#   ' Ws': '26',
#   'Rain ': '8.3',
#   'FFMC': '47.4',
#   'DMC': '1.1',
#   'DC': '7',
#   'ISI': '0.4',
#   'BUI': '1.6',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '15',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '24',
#   ' RH': '82',
#   ' Ws': '15',
#   'Rain ': '0.4',
#   'FFMC': '44.9',
#   'DMC': '0.9',
#   'DC': '7.3',
#   'ISI': '0.2',
#   'BUI': '1.4',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '16',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '65',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '78.1',
#   'DMC': '3.2',
#   'DC': '15.7',
#   'ISI': '1.9',
#   'BUI': '4.2',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '17',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '52',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '87.7',
#   'DMC': '6.4',
#   'DC': '24.3',
#   'ISI': '6.2',
#   'BUI': '7.7',
#   'FWI': '5.9',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '49',
#   ' Ws': '11',
#   'Rain ': '0',
#   'FFMC': '89.4',
#   'DMC': '9.8',
#   'DC': '33.1',
#   'ISI': '6.8',
#   'BUI': '11.3',
#   'FWI': '7.7',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '57',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '89.3',
#   'DMC': '12.5',
#   'DC': '41.3',
#   'ISI': '7.8',
#   'BUI': '14.2',
#   'FWI': '9.7',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '84',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '83.8',
#   'DMC': '13.5',
#   'DC': '49.3',
#   'ISI': '4.5',
#   'BUI': '16',
#   'FWI': '6.3',
#   'Classes  ': 'fire'},
#  {'day': '21',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '55',
#   ' Ws': '11',
#   'Rain ': '0',
#   'FFMC': '87.8',
#   'DMC': '16.5',
#   'DC': '57.9',
#   'ISI': '5.4',
#   'BUI': '19.2',
#   'FWI': '8.3',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '50',
#   ' Ws': '19',
#   'Rain ': '0.6',
#   'FFMC': '77.8',
#   'DMC': '10.6',
#   'DC': '41.4',
#   'ISI': '2.4',
#   'BUI': '12.9',
#   'FWI': '2.8',
#   'Classes  ': 'not fire   '},
#  {'day': '23',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '54',
#   ' Ws': '11',
#   'Rain ': '0.5',
#   'FFMC': '73.7',
#   'DMC': '7.9',
#   'DC': '30.4',
#   'ISI': '1.2',
#   'BUI': '9.6',
#   'FWI': '0.7',
#   'Classes  ': 'not fire   '},
#  {'day': '24',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '65',
#   ' Ws': '19',
#   'Rain ': '0.6',
#   'FFMC': '68.3',
#   'DMC': '5.5',
#   'DC': '15.2',
#   'ISI': '1.5',
#   'BUI': '5.8',
#   'FWI': '0.7',
#   'Classes  ': 'not fire   '},
#  {'day': '25',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '26',
#   ' RH': '81',
#   ' Ws': '21',
#   'Rain ': '5.8',
#   'FFMC': '48.6',
#   'DMC': '3',
#   'DC': '7.7',
#   'ISI': '0.4',
#   'BUI': '3',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '26',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '54',
#   ' Ws': '11',
#   'Rain ': '0',
#   'FFMC': '82',
#   'DMC': '6',
#   'DC': '16.3',
#   'ISI': '2.5',
#   'BUI': '6.2',
#   'FWI': '1.7',
#   'Classes  ': 'not fire   '},
#  {'day': '27',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '66',
#   ' Ws': '11',
#   'Rain ': '0',
#   'FFMC': '85.7',
#   'DMC': '8.3',
#   'DC': '24.9',
#   'ISI': '4',
#   'BUI': '9',
#   'FWI': '4.1',
#   'Classes  ': 'fire   '},
#  {'day': '28',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '47',
#   ' Ws': '14',
#   'Rain ': '0.7',
#   'FFMC': '77.5',
#   'DMC': '7.1',
#   'DC': '8.8',
#   'ISI': '1.8',
#   'BUI': '6.8',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '29',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '26',
#   ' RH': '80',
#   ' Ws': '16',
#   'Rain ': '1.8',
#   'FFMC': '47.4',
#   'DMC': '2.9',
#   'DC': '7.7',
#   'ISI': '0.3',
#   'BUI': '3',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '30',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '25',
#   ' RH': '78',
#   ' Ws': '14',
#   'Rain ': '1.4',
#   'FFMC': '45',
#   'DMC': '1.9',
#   'DC': '7.5',
#   'ISI': '0.2',
#   'BUI': '2.4',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': 'Sidi-Bel Abbes Region Dataset',
#   'month': nan,
#   'year': nan,
#   'Temperature': nan,
#   ' RH': nan,
#   ' Ws': nan,
#   'Rain ': nan,
#   'FFMC': nan,
#   'DMC': nan,
#   'DC': nan,
#   'ISI': nan,
#   'BUI': nan,
#   'FWI': nan,
#   'Classes  ': nan},
#  {'day': 'day',
#   'month': 'month',
#   'year': 'year',
#   'Temperature': 'Temperature',
#   ' RH': ' RH',
#   ' Ws': ' Ws',
#   'Rain ': 'Rain ',
#   'FFMC': 'FFMC',
#   'DMC': 'DMC',
#   'DC': 'DC',
#   'ISI': 'ISI',
#   'BUI': 'BUI',
#   'FWI': 'FWI',
#   'Classes  ': 'Classes  '},
#  {'day': '01',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '71',
#   ' Ws': '12',
#   'Rain ': '0.7',
#   'FFMC': '57.1',
#   'DMC': '2.5',
#   'DC': '8.2',
#   'ISI': '0.6',
#   'BUI': '2.8',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '73',
#   ' Ws': '13',
#   'Rain ': '4',
#   'FFMC': '55.7',
#   'DMC': '2.7',
#   'DC': '7.8',
#   'ISI': '0.6',
#   'BUI': '2.9',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '03',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '80',
#   ' Ws': '14',
#   'Rain ': '2',
#   'FFMC': '48.7',
#   'DMC': '2.2',
#   'DC': '7.6',
#   'ISI': '0.3',
#   'BUI': '2.6',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '04',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '64',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '79.4',
#   'DMC': '5.2',
#   'DC': '15.4',
#   'ISI': '2.2',
#   'BUI': '5.6',
#   'FWI': '1',
#   'Classes  ': 'not fire   '},
#  {'day': '05',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '60',
#   ' Ws': '14',
#   'Rain ': '0.2',
#   'FFMC': '77.1',
#   'DMC': '6',
#   'DC': '17.6',
#   'ISI': '1.8',
#   'BUI': '6.5',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '06',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '54',
#   ' Ws': '11',
#   'Rain ': '0.1',
#   'FFMC': '83.7',
#   'DMC': '8.4',
#   'DC': '26.3',
#   'ISI': '3.1',
#   'BUI': '9.3',
#   'FWI': '3.1',
#   'Classes  ': 'fire   '},
#  {'day': '07',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '44',
#   ' Ws': '17',
#   'Rain ': '0.2',
#   'FFMC': '85.6',
#   'DMC': '9.9',
#   'DC': '28.9',
#   'ISI': '5.4',
#   'BUI': '10.7',
#   'FWI': '6',
#   'Classes  ': 'fire   '},
#  {'day': '08',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '51',
#   ' Ws': '17',
#   'Rain ': '1.3',
#   'FFMC': '71.4',
#   'DMC': '7.7',
#   'DC': '7.4',
#   'ISI': '1.5',
#   'BUI': '7.3',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '09',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '59',
#   ' Ws': '18',
#   'Rain ': '0.1',
#   'FFMC': '78.1',
#   'DMC': '8.5',
#   'DC': '14.7',
#   'ISI': '2.4',
#   'BUI': '8.3',
#   'FWI': '1.9',
#   'Classes  ': 'not fire   '},
#  {'day': '10',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '41',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '89.4',
#   'DMC': '13.3',
#   'DC': '22.5',
#   'ISI': '8.4',
#   'BUI': '13.1',
#   'FWI': '10',
#   'Classes  ': 'fire   '},
#  {'day': '11',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '42',
#   ' Ws': '21',
#   'Rain ': '0',
#   'FFMC': '90.6',
#   'DMC': '18.2',
#   'DC': '30.5',
#   'ISI': '13.4',
#   'BUI': '18',
#   'FWI': '16.7',
#   'Classes  ': 'fire   '},
#  {'day': '12',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '58',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '21.3',
#   'DC': '37.8',
#   'ISI': '8.7',
#   'BUI': '21.2',
#   'FWI': '12.9',
#   'Classes  ': 'fire   '},
#  {'day': '13',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '52',
#   ' Ws': '15',
#   'Rain ': '2',
#   'FFMC': '72.3',
#   'DMC': '11.4',
#   'DC': '7.8',
#   'ISI': '1.4',
#   'BUI': '10.9',
#   'FWI': '0.9',
#   'Classes  ': 'not fire   '},
#  {'day': '14',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '79',
#   ' Ws': '16',
#   'Rain ': '0.7',
#   'FFMC': '53.4',
#   'DMC': '6.4',
#   'DC': '7.3',
#   'ISI': '0.5',
#   'BUI': '6.1',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '15',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '90',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '66.8',
#   'DMC': '7.2',
#   'DC': '14.7',
#   'ISI': '1.2',
#   'BUI': '7.1',
#   'FWI': '0.6',
#   'Classes  ': 'not fire   '},
#  {'day': '16',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '87',
#   ' Ws': '15',
#   'Rain ': '0.4',
#   'FFMC': '47.4',
#   'DMC': '4.2',
#   'DC': '8',
#   'ISI': '0.2',
#   'BUI': '4.1',
#   'FWI': '0.1',
#   'Classes  ': 'not fire   '},
#  {'day': '17',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '69',
#   ' Ws': '17',
#   'Rain ': '4.7',
#   'FFMC': '62.2',
#   'DMC': '3.9',
#   'DC': '8',
#   'ISI': '1.1',
#   'BUI': '3.8',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '18',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '62',
#   ' Ws': '10',
#   'Rain ': '8.7',
#   'FFMC': '65.5',
#   'DMC': '4.6',
#   'DC': '8.3',
#   'ISI': '0.9',
#   'BUI': '4.4',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '19',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '67',
#   ' Ws': '14',
#   'Rain ': '4.5',
#   'FFMC': '64.6',
#   'DMC': '4.4',
#   'DC': '8.2',
#   'ISI': '1',
#   'BUI': '4.2',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '20',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '72',
#   ' Ws': '14',
#   'Rain ': '0.2',
#   'FFMC': '60.2',
#   'DMC': '3.8',
#   'DC': '8',
#   'ISI': '0.8',
#   'BUI': '3.7',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '21',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '55',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '86.2',
#   'DMC': '8.3',
#   'DC': '18.4',
#   'ISI': '5',
#   'BUI': '8.2',
#   'FWI': '4.9',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '46',
#   ' Ws': '14',
#   'Rain ': '1.1',
#   'FFMC': '78.3',
#   'DMC': '8.1',
#   'DC': '8.3',
#   'ISI': '1.9',
#   'BUI': '7.7',
#   'FWI': '1.2',
#   'Classes  ': 'not fire   '},
#  {'day': '23',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '59',
#   ' Ws': '16',
#   'Rain ': '0.8',
#   'FFMC': '74.2',
#   'DMC': '7',
#   'DC': '8.3',
#   'ISI': '1.6',
#   'BUI': '6.7',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '24',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '68',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '85.3',
#   'DMC': '10',
#   'DC': '17',
#   'ISI': '4.9',
#   'BUI': '9.9',
#   'FWI': '5.3',
#   'Classes  ': 'fire   '},
#  {'day': '25',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '70',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '86',
#   'DMC': '12.8',
#   'DC': '25.6',
#   'ISI': '5.4',
#   'BUI': '12.7',
#   'FWI': '6.7',
#   'Classes  ': 'fire   '},
#  {'day': '26',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '62',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '87.8',
#   'DMC': '16.5',
#   'DC': '34.5',
#   'ISI': '7',
#   'BUI': '16.4',
#   'FWI': '9.5',
#   'Classes  ': 'fire   '},
#  {'day': '27',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '55',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '89.1',
#   'DMC': '20.9',
#   'DC': '43.3',
#   'ISI': '8',
#   'BUI': '20.8',
#   'FWI': '12',
#   'Classes  ': 'fire   '},
#  {'day': '28',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '37',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '92.5',
#   'DMC': '27.2',
#   'DC': '52.4',
#   'ISI': '11.7',
#   'BUI': '27.1',
#   'FWI': '18.4',
#   'Classes  ': 'fire   '},
#  {'day': '29',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '36',
#   ' Ws': '13',
#   'Rain ': '0.6',
#   'FFMC': '86.2',
#   'DMC': '17.9',
#   'DC': '36.7',
#   'ISI': '4.8',
#   'BUI': '17.8',
#   'FWI': '7.2',
#   'Classes  ': 'fire   '},
#  {'day': '30',
#   'month': '06',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '42',
#   ' Ws': '15',
#   'Rain ': '1.7',
#   'FFMC': '79.7',
#   'DMC': '12',
#   'DC': '8.5',
#   'ISI': '2.2',
#   'BUI': '11.5',
#   'FWI': '2.2',
#   'Classes  ': 'not fire     '},
#  {'day': '01',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '58',
#   ' Ws': '18',
#   'Rain ': '2.2',
#   'FFMC': '63.7',
#   'DMC': '3.2',
#   'DC': '8.5',
#   'ISI': '1.2',
#   'BUI': '3.3',
#   'FWI': '0.5',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '48',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '87.6',
#   'DMC': '7.9',
#   'DC': '17.8',
#   'ISI': '6.8',
#   'BUI': '7.8',
#   'FWI': '6.4',
#   'Classes  ': 'fire   '},
#  {'day': '03',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '56',
#   ' Ws': '17',
#   'Rain ': '0.1',
#   'FFMC': '84.7',
#   'DMC': '9.7',
#   'DC': '27.3',
#   'ISI': '4.7',
#   'BUI': '10.3',
#   'FWI': '5.2',
#   'Classes  ': 'fire   '},
#  {'day': '04',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '58',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '88',
#   'DMC': '13.6',
#   'DC': '36.8',
#   'ISI': '8',
#   'BUI': '14.1',
#   'FWI': '9.9',
#   'Classes  ': 'fire   '},
#  {'day': '05',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '45',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '90.5',
#   'DMC': '18.7',
#   'DC': '46.4',
#   'ISI': '11.3',
#   'BUI': '18.7',
#   'FWI': '15',
#   'Classes  ': 'fire   '},
#  {'day': '06',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '42',
#   ' Ws': '15',
#   'Rain ': '0.3',
#   'FFMC': '84.7',
#   'DMC': '15.5',
#   'DC': '45.1',
#   'ISI': '4.3',
#   'BUI': '16.7',
#   'FWI': '6.3',
#   'Classes  ': 'fire   '},
#  {'day': '07',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '38',
#   ' RH': '43',
#   ' Ws': '13',
#   'Rain ': '0.5',
#   'FFMC': '85',
#   'DMC': '13',
#   'DC': '35.4',
#   'ISI': '4.1',
#   'BUI': '13.7',
#   'FWI': '5.2',
#   'Classes  ': 'fire   '},
#  {'day': '08',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '47',
#   ' Ws': '18',
#   'Rain ': '6',
#   'FFMC': '80.8',
#   'DMC': '9.8',
#   'DC': '9.7',
#   'ISI': '3.1',
#   'BUI': '9.4',
#   'FWI': '3',
#   'Classes  ': 'fire   '},
#  {'day': '09',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '43',
#   ' Ws': '15',
#   'Rain ': '1.9',
#   'FFMC': '82.3',
#   'DMC': '9.4',
#   'DC': '9.9',
#   'ISI': '3.2',
#   'BUI': '9',
#   'FWI': '3.1',
#   'Classes  ': 'fire   '},
#  {'day': '10',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '51',
#   ' Ws': '16',
#   'Rain ': '3.8',
#   'FFMC': '77.5',
#   'DMC': '8',
#   'DC': '9.5',
#   'ISI': '2',
#   'BUI': '7.7',
#   'FWI': '1.3',
#   'Classes  ': 'not fire   '},
#  {'day': '11',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '56',
#   ' Ws': '15',
#   'Rain ': '2.9',
#   'FFMC': '74.8',
#   'DMC': '7.1',
#   'DC': '9.5',
#   'ISI': '1.6',
#   'BUI': '6.8',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '12',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '44',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '90.1',
#   'DMC': '12.6',
#   'DC': '19.4',
#   'ISI': '8.3',
#   'BUI': '12.5',
#   'FWI': '9.6',
#   'Classes  ': 'fire   '},
#  {'day': '13',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '45',
#   ' Ws': '13',
#   'Rain ': '0.6',
#   'FFMC': '85.2',
#   'DMC': '11.3',
#   'DC': '10.4',
#   'ISI': '4.2',
#   'BUI': '10.9',
#   'FWI': '4.7',
#   'Classes  ': 'fire   '},
#  {'day': '14',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '37',
#   ' Ws': '18',
#   'Rain ': '0.2',
#   'FFMC': '88.9',
#   'DMC': '12.9',
#   'DC': '14.6 9',
#   'ISI': '12.5',
#   'BUI': '10.4',
#   'FWI': 'fire   ',
#   'Classes  ': nan},
#  {'day': '15',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '45',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '90.5',
#   'DMC': '18',
#   'DC': '24.1',
#   'ISI': '10.9',
#   'BUI': '17.7',
#   'FWI': '14.1',
#   'Classes  ': 'fire   '},
#  {'day': '16',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '83',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '84.5',
#   'DMC': '19.4',
#   'DC': '33.1',
#   'ISI': '4.7',
#   'BUI': '19.2',
#   'FWI': '7.3',
#   'Classes  ': 'fire   '},
#  {'day': '17',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '81',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '84.6',
#   'DMC': '21.1',
#   'DC': '42.3',
#   'ISI': '4.7',
#   'BUI': '20.9',
#   'FWI': '7.7',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '68',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86.1',
#   'DMC': '23.9',
#   'DC': '51.6',
#   'ISI': '5.2',
#   'BUI': '23.9',
#   'FWI': '9.1',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '58',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '88.1',
#   'DMC': '27.8',
#   'DC': '61.1',
#   'ISI': '7.3',
#   'BUI': '27.7',
#   'FWI': '13',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '50',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '89.9',
#   'DMC': '32.7',
#   'DC': '71',
#   'ISI': '9.5',
#   'BUI': '32.6',
#   'FWI': '17.3',
#   'Classes  ': 'fire   '},
#  {'day': '21',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '29',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '93.9',
#   'DMC': '39.6',
#   'DC': '80.6',
#   'ISI': '18.5',
#   'BUI': '39.5',
#   'FWI': '30',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '48',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '91.5',
#   'DMC': '44.2',
#   'DC': '90.1',
#   'ISI': '13.2',
#   'BUI': '44',
#   'FWI': '25.4',
#   'Classes  ': 'fire   '},
#  {'day': '23',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '71',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '87.3',
#   'DMC': '46.6',
#   'DC': '99',
#   'ISI': '6.9',
#   'BUI': '46.5',
#   'FWI': '16.3',
#   'Classes  ': 'fire   '},
#  {'day': '24',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '63',
#   ' Ws': '17',
#   'Rain ': '1.1',
#   'FFMC': '72.8',
#   'DMC': '20.9',
#   'DC': '56.6',
#   'ISI': '1.6',
#   'BUI': '21.7',
#   'FWI': '2.5',
#   'Classes  ': 'not fire   '},
#  {'day': '25',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '64',
#   ' Ws': '9',
#   'Rain ': '1.2',
#   'FFMC': '73.8',
#   'DMC': '11.7',
#   'DC': '15.9',
#   'ISI': '1.1',
#   'BUI': '11.4',
#   'FWI': '0.7',
#   'Classes  ': 'not fire   '},
#  {'day': '26',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '58',
#   ' Ws': '10',
#   'Rain ': '0.2',
#   'FFMC': '78.3',
#   'DMC': '10.8',
#   'DC': '19.7',
#   'ISI': '1.6',
#   'BUI': '10.7',
#   'FWI': '1',
#   'Classes  ': 'not fire   '},
#  {'day': '27',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '87',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '80',
#   'DMC': '11.8',
#   'DC': '28.3',
#   'ISI': '2.8',
#   'BUI': '11.8',
#   'FWI': '3.2',
#   'Classes  ': 'not fire   '},
#  {'day': '28',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '57',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '87.5',
#   'DMC': '15.7',
#   'DC': '37.6',
#   'ISI': '6.7',
#   'BUI': '15.7',
#   'FWI': '9',
#   'Classes  ': 'fire   '},
#  {'day': '29',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '59',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '88.1',
#   'DMC': '19.5',
#   'DC': '47.2',
#   'ISI': '7.4',
#   'BUI': '19.5',
#   'FWI': '10.9',
#   'Classes  ': 'fire   '},
#  {'day': '30',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '56',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '23.8',
#   'DC': '57.1',
#   'ISI': '8.2',
#   'BUI': '23.8',
#   'FWI': '13.2',
#   'Classes  ': 'fire   '},
#  {'day': '31',
#   'month': '07',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '55',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '89.3',
#   'DMC': '28.3',
#   'DC': '67.2',
#   'ISI': '8.3',
#   'BUI': '28.3',
#   'FWI': '14.5',
#   'Classes  ': 'fire   '},
#  {'day': '01',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '38',
#   ' RH': '52',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '78.3',
#   'DMC': '4.4',
#   'DC': '10.5',
#   'ISI': '2',
#   'BUI': '4.4',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '40',
#   ' RH': '34',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '93.3',
#   'DMC': '10.8',
#   'DC': '21.4',
#   'ISI': '13.8',
#   'BUI': '10.6',
#   'FWI': '13.5',
#   'Classes  ': 'fire   '},
#  {'day': '03',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '33',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '93.7',
#   'DMC': '17.1',
#   'DC': '32.1',
#   'ISI': '17.2',
#   'BUI': '16.9',
#   'FWI': '19.5',
#   'Classes  ': 'fire   '},
#  {'day': '04',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '38',
#   ' RH': '35',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '93.8',
#   'DMC': '23',
#   'DC': '42.7',
#   'ISI': '15.7',
#   'BUI': '22.9',
#   'FWI': '20.9',
#   'Classes  ': 'fire   '},
#  {'day': '05',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '42',
#   ' Ws': '17',
#   'Rain ': '0.1',
#   'FFMC': '88.3',
#   'DMC': '23.6',
#   'DC': '52.5',
#   'ISI': '19',
#   'BUI': '23.5',
#   'FWI': '12.6',
#   'Classes  ': 'fire   '},
#  {'day': '06',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '54',
#   ' Ws': '14',
#   'Rain ': '3.1',
#   'FFMC': '70.5',
#   'DMC': '11',
#   'DC': '9.1',
#   'ISI': '1.3',
#   'BUI': '10.5',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '07',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '63',
#   ' Ws': '13',
#   'Rain ': '2.9',
#   'FFMC': '69.7',
#   'DMC': '7.2',
#   'DC': '9.8',
#   'ISI': '1.2',
#   'BUI': '6.9',
#   'FWI': '0.6',
#   'Classes  ': 'not fire   '},
#  {'day': '08',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '56',
#   ' Ws': '11',
#   'Rain ': '0',
#   'FFMC': '87.4',
#   'DMC': '11.2',
#   'DC': '20.2',
#   'ISI': '5.2',
#   'BUI': '11',
#   'FWI': '5.9',
#   'Classes  ': 'fire   '},
#  {'day': '09',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '43',
#   ' Ws': '12',
#   'Rain ': '0',
#   'FFMC': '91.7',
#   'DMC': '16.5',
#   'DC': '30.9',
#   'ISI': '9.6',
#   'BUI': '16.4',
#   'FWI': '12.7',
#   'Classes  ': 'fire   '},
#  {'day': '10',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '39',
#   ' Ws': '15',
#   'Rain ': '0.2',
#   'FFMC': '89.3',
#   'DMC': '15.8',
#   'DC': '35.4',
#   'ISI': '8.2',
#   'BUI': '15.8',
#   'FWI': '10.7',
#   'Classes  ': 'fire   '},
#  {'day': '11',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '40',
#   ' RH': '31',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '94.2',
#   'DMC': '22.5',
#   'DC': '46.3',
#   'ISI': '16.6',
#   'BUI': '22.4',
#   'FWI': '21.6',
#   'Classes  ': 'fire   '},
#  {'day': '12',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '39',
#   ' RH': '21',
#   ' Ws': '17',
#   'Rain ': '0.4',
#   'FFMC': '93',
#   'DMC': '18.4',
#   'DC': '41.5',
#   'ISI': '15.5',
#   'BUI': '18.4',
#   'FWI': '18.8',
#   'Classes  ': 'fire   '},
#  {'day': '13',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '34',
#   ' Ws': '16',
#   'Rain ': '0.2',
#   'FFMC': '88.3',
#   'DMC': '16.9',
#   'DC': '45.1',
#   'ISI': '7.5',
#   'BUI': '17.5',
#   'FWI': '10.5',
#   'Classes  ': 'fire   '},
#  {'day': '14',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '40',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '91.9',
#   'DMC': '22.3',
#   'DC': '55.5',
#   'ISI': '10.8',
#   'BUI': '22.3',
#   'FWI': '15.7',
#   'Classes  ': 'fire   '},
#  {'day': '15',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '46',
#   ' Ws': '13',
#   'Rain ': '0.3',
#   'FFMC': '83.9',
#   'DMC': '16.9',
#   'DC': '54.2',
#   'ISI': '3.5',
#   'BUI': '19',
#   'FWI': '5.5',
#   'Classes  ': 'fire   '},
#  {'day': '16',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '40',
#   ' RH': '41',
#   ' Ws': '10',
#   'Rain ': '0.1',
#   'FFMC': '92',
#   'DMC': '22.6',
#   'DC': '65.1',
#   'ISI': '9.5',
#   'BUI': '24.2',
#   'FWI': '14.8',
#   'Classes  ': 'fire   '},
#  {'day': '17',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '42',
#   ' RH': '24',
#   ' Ws': '9',
#   'Rain ': '0',
#   'FFMC': '96',
#   'DMC': '30.3',
#   'DC': '76.4',
#   'ISI': '15.7',
#   'BUI': '30.4',
#   'FWI': '24',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '37',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '94.3',
#   'DMC': '35.9',
#   'DC': '86.8',
#   'ISI': '16',
#   'BUI': '35.9',
#   'FWI': '26.3',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '66',
#   ' Ws': '15',
#   'Rain ': '0.1',
#   'FFMC': '82.7',
#   'DMC': '32.7',
#   'DC': '96.8',
#   'ISI': '3.3',
#   'BUI': '35.5',
#   'FWI': '7.7',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '81',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '83.7',
#   'DMC': '34.4',
#   'DC': '107',
#   'ISI': '3.8',
#   'BUI': '38.1',
#   'FWI': '9',
#   'Classes  ': 'fire   '},
#  {'day': '21',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '71',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '86',
#   'DMC': '36.9',
#   'DC': '117.1',
#   'ISI': '5.1',
#   'BUI': '41.3',
#   'FWI': '12.2',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '37',
#   ' RH': '53',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '89.5',
#   'DMC': '41.1',
#   'DC': '127.5',
#   'ISI': '8',
#   'BUI': '45.5',
#   'FWI': '18.1',
#   'Classes  ': 'fire   '},
#  {'day': '23',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '43',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '91.2',
#   'DMC': '46.1',
#   'DC': '137.7',
#   'ISI': '11.5',
#   'BUI': '50.2',
#   'FWI': '24.5',
#   'Classes  ': 'fire   '},
#  {'day': '24',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '38',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '92.1',
#   'DMC': '51.3',
#   'DC': '147.7',
#   'ISI': '12.2',
#   'BUI': '54.9',
#   'FWI': '26.9',
#   'Classes  ': 'fire   '},
#  {'day': '25',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '40',
#   ' Ws': '18',
#   'Rain ': '0',
#   'FFMC': '92.1',
#   'DMC': '56.3',
#   'DC': '157.5',
#   'ISI': '14.3',
#   'BUI': '59.5',
#   'FWI': '31.1',
#   'Classes  ': 'fire   '},
#  {'day': '26',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '37',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '92.2',
#   'DMC': '61.3',
#   'DC': '167.2',
#   'ISI': '13.1',
#   'BUI': '64',
#   'FWI': '30.3',
#   'Classes  ': 'fire   '},
#  {'day': '27',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '54',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '91',
#   'DMC': '65.9',
#   'DC': '177.3',
#   'ISI': '10',
#   'BUI': '68',
#   'FWI': '26.1',
#   'Classes  ': 'fire   '},
#  {'day': '28',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '56',
#   ' Ws': '14',
#   'Rain ': '0.4',
#   'FFMC': '79.2',
#   'DMC': '37',
#   'DC': '166',
#   'ISI': '2.1',
#   'BUI': '30.6',
#   'FWI': '6.1',
#   'Classes  ': 'not fire   '},
#  {'day': '29',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '53',
#   ' Ws': '17',
#   'Rain ': '0.5',
#   'FFMC': '80.2',
#   'DMC': '20.7',
#   'DC': '149.2',
#   'ISI': '2.7',
#   'BUI': '30.6',
#   'FWI': '5.9',
#   'Classes  ': 'fire   '},
#  {'day': '30',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '49',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '89.2',
#   'DMC': '24.8',
#   'DC': '159.1',
#   'ISI': '8.1',
#   'BUI': '35.7',
#   'FWI': '16',
#   'Classes  ': 'fire   '},
#  {'day': '31',
#   'month': '08',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '59',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '89.1',
#   'DMC': '27.8',
#   'DC': '168.2',
#   'ISI': '9.8',
#   'BUI': '39.3',
#   'FWI': '19.4',
#   'Classes  ': 'fire   '},
#  {'day': '01',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '86',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '37.9',
#   'DMC': '0.9',
#   'DC': '8.2',
#   'ISI': '0.1',
#   'BUI': '1.4',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '02',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '67',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '75.4',
#   'DMC': '2.9',
#   'DC': '16.3',
#   'ISI': '2',
#   'BUI': '4',
#   'FWI': '0.8',
#   'Classes  ': 'not fire   '},
#  {'day': '03',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '75',
#   ' Ws': '16',
#   'Rain ': '0',
#   'FFMC': '82.2',
#   'DMC': '4.4',
#   'DC': '24.3',
#   'ISI': '3.3',
#   'BUI': '6',
#   'FWI': '2.5',
#   'Classes  ': 'fire   '},
#  {'day': '04',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '66',
#   ' Ws': '15',
#   'Rain ': '0.2',
#   'FFMC': '73.5',
#   'DMC': '4.1',
#   'DC': '26.6',
#   'ISI': '1.5',
#   'BUI': '6',
#   'FWI': '0.7',
#   'Classes  ': 'not fire   '},
#  {'day': '05',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '58',
#   ' Ws': '12',
#   'Rain ': '4.1',
#   'FFMC': '66.1',
#   'DMC': '4',
#   'DC': '8.4',
#   'ISI': '1',
#   'BUI': '3.9',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '06',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '71',
#   ' Ws': '14',
#   'Rain ': '6.5',
#   'FFMC': '64.5',
#   'DMC': '3.3',
#   'DC': '9.1',
#   'ISI': '1',
#   'BUI': '3.5',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '07',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '62',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '83.3',
#   'DMC': '5.8',
#   'DC': '17.7',
#   'ISI': '3.8',
#   'BUI': '6.4',
#   'FWI': '3.2',
#   'Classes  ': 'fire   '},
#  {'day': '08',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '88',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '82.5',
#   'DMC': '6.6',
#   'DC': '26.1',
#   'ISI': '3',
#   'BUI': '8.1',
#   'FWI': '2.7',
#   'Classes  ': 'fire   '},
#  {'day': '09',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '80',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '83.1',
#   'DMC': '7.9',
#   'DC': '34.5',
#   'ISI': '3.5',
#   'BUI': '10',
#   'FWI': '3.7',
#   'Classes  ': 'fire   '},
#  {'day': '10',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '74',
#   ' Ws': '15',
#   'Rain ': '1.1',
#   'FFMC': '59.5',
#   'DMC': '4.7',
#   'DC': '8.2',
#   'ISI': '0.8',
#   'BUI': '4.6',
#   'FWI': '0.3',
#   'Classes  ': 'not fire   '},
#  {'day': '11',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '73',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '79.2',
#   'DMC': '6.5',
#   'DC': '16.6',
#   'ISI': '2.1',
#   'BUI': '6.6',
#   'FWI': '1.2',
#   'Classes  ': 'not fire   '},
#  {'day': '12',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '31',
#   ' RH': '72',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '84.2',
#   'DMC': '8.3',
#   'DC': '25.2',
#   'ISI': '3.8',
#   'BUI': '9.1',
#   'FWI': '3.9',
#   'Classes  ': 'fire   '},
#  {'day': '13',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '49',
#   ' Ws': '19',
#   'Rain ': '0',
#   'FFMC': '88.6',
#   'DMC': '11.5',
#   'DC': '33.4',
#   'ISI': '9.1',
#   'BUI': '12.4',
#   'FWI': '10.3',
#   'Classes  ': 'fire   '},
#  {'day': '14',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '81',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '84.6',
#   'DMC': '12.6',
#   'DC': '41.5',
#   'ISI': '4.3',
#   'BUI': '14.3',
#   'FWI': '5.7',
#   'Classes  ': 'fire   '},
#  {'day': '15',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '32',
#   ' RH': '51',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '88.7',
#   'DMC': '16',
#   'DC': '50.2',
#   'ISI': '6.9',
#   'BUI': '17.8',
#   'FWI': '9.8',
#   'Classes  ': 'fire   '},
#  {'day': '16',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '26',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '93.9',
#   'DMC': '21.2',
#   'DC': '59.2',
#   'ISI': '14.2',
#   'BUI': '22.4',
#   'FWI': '19.3',
#   'Classes  ': 'fire   '},
#  {'day': '17',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '44',
#   ' Ws': '12',
#   'Rain ': '0',
#   'FFMC': '92.5',
#   'DMC': '25.2',
#   'DC': '63.3',
#   'ISI': '11.2',
#   'BUI': '26.2',
#   'FWI': '17.5',
#   'Classes  ': 'fire   '},
#  {'day': '18',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '36',
#   ' RH': '33',
#   ' Ws': '13',
#   'Rain ': '0.1',
#   'FFMC': '90.6',
#   'DMC': '25.8',
#   'DC': '77.8',
#   'ISI': '9',
#   'BUI': '28.2',
#   'FWI': '15.4',
#   'Classes  ': 'fire   '},
#  {'day': '19',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '29',
#   ' RH': '41',
#   ' Ws': '8',
#   'Rain ': '0.1',
#   'FFMC': '83.9',
#   'DMC': '24.9',
#   'DC': '86',
#   'ISI': '2.7',
#   'BUI': '28.9',
#   'FWI': '5.6',
#   'Classes  ': 'fire   '},
#  {'day': '20',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '34',
#   ' RH': '58',
#   ' Ws': '13',
#   'Rain ': '0.2',
#   'FFMC': '79.5',
#   'DMC': '18.7',
#   'DC': '88',
#   'ISI': '2.1',
#   'BUI': '24.4',
#   'FWI': '3.8',
#   'Classes  ': 'not fire   '},
#  {'day': '21',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '34',
#   ' Ws': '17',
#   'Rain ': '0',
#   'FFMC': '92.2',
#   'DMC': '23.6',
#   'DC': '97.3',
#   'ISI': '13.8',
#   'BUI': '29.4',
#   'FWI': '21.6',
#   'Classes  ': 'fire   '},
#  {'day': '22',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '33',
#   ' RH': '64',
#   ' Ws': '13',
#   'Rain ': '0',
#   'FFMC': '88.9',
#   'DMC': '26.1',
#   'DC': '106.3',
#   'ISI': '7.1',
#   'BUI': '32.4',
#   'FWI': '13.7',
#   'Classes  ': 'fire   '},
#  {'day': '23',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '35',
#   ' RH': '56',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '89',
#   'DMC': '29.4',
#   'DC': '115.6',
#   'ISI': '7.5',
#   'BUI': '36',
#   'FWI': '15.2',
#   'Classes  ': 'fire   '},
#  {'day': '24',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '26',
#   ' RH': '49',
#   ' Ws': '6',
#   'Rain ': '2',
#   'FFMC': '61.3',
#   'DMC': '11.9',
#   'DC': '28.1',
#   'ISI': '0.6',
#   'BUI': '11.9',
#   'FWI': '0.4',
#   'Classes  ': 'not fire   '},
#  {'day': '25',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '70',
#   ' Ws': '15',
#   'Rain ': '0',
#   'FFMC': '79.9',
#   'DMC': '13.8',
#   'DC': '36.1',
#   'ISI': '2.4',
#   'BUI': '14.1',
#   'FWI': '3',
#   'Classes  ': 'not fire   '},
#  {'day': '26',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '30',
#   ' RH': '65',
#   ' Ws': '14',
#   'Rain ': '0',
#   'FFMC': '85.4',
#   'DMC': '16',
#   'DC': '44.5',
#   'ISI': '4.5',
#   'BUI': '16.9',
#   'FWI': '6.5',
#   'Classes  ': 'fire   '},
#  {'day': '27',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '28',
#   ' RH': '87',
#   ' Ws': '15',
#   'Rain ': '4.4',
#   'FFMC': '41.1',
#   'DMC': '6.5',
#   'DC': '8',
#   'ISI': '0.1',
#   'BUI': '6.2',
#   'FWI': '0',
#   'Classes  ': 'not fire   '},
#  {'day': '28',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '27',
#   ' RH': '87',
#   ' Ws': '29',
#   'Rain ': '0.5',
#   'FFMC': '45.9',
#   'DMC': '3.5',
#   'DC': '7.9',
#   'ISI': '0.4',
#   'BUI': '3.4',
#   'FWI': '0.2',
#   'Classes  ': 'not fire   '},
#  {'day': '29',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '24',
#   ' RH': '54',
#   ' Ws': '18',
#   'Rain ': '0.1',
#   'FFMC': '79.7',
#   'DMC': '4.3',
#   'DC': '15.2',
#   'ISI': '1.7',
#   'BUI': '5.1',
#   'FWI': '0.7',
#   'Classes  ': 'not fire   '},
#  {'day': '30',
#   'month': '09',
#   'year': '2012',
#   'Temperature': '24',
#   ' RH': '64',
#   ' Ws': '15',
#   'Rain ': '0.2',
#   'FFMC': '67.3',
#   'DMC': '3.8',
#   'DC': '16.5',
#   'ISI': '1.2',
#   'BUI': '4.8',
#   'FWI': '0.5',
#   'Classes  ': 'not fire    '}]
