# %% [markdown]
# #### Mean

# %%
import numpy as np

# %%
ages=[12,13,45,62,7,8,76,56,4,34,6,17,17,5,4,3,45,16]

# %%
np.mean(ages)
# Out:
# 23.88888888888889

# %%
weights=[56,45,78,58,49,37,58,79,60]

# %%
np.mean(weights)
# Out:
# 57.77777777777778

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %% [markdown]
# #### Median

# %%
ages
# Out:
# [12, 13, 45, 62, 7, 8, 76, 56, 4, 34, 6, 17, 17, 5, 4, 3, 45, 16]

# %%
np.median(ages)
# Out:
# 14.5

# %%
np.mean(ages)
# Out:
# 23.88888888888889

# %%
agesOut=[12, 13, 45, 62, 7, 8, 76, 56, 4, 34, 6, 17, 17, 5, 4, 3, 45, 16,300]

# %%
np.median(agesOut)   # 14.5 to 16   ,,, miner change
# Out:
# 16.0

# %%
np.mean(agesOut)      # 23.8 to 38.42  big change
# Out:
# 38.421052631578945

# %% [markdown]
# #### Mode

# %%
pip install scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scipy
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/43/d0/f3cd75b62e1b90f48dbf091261b2fc7ceec14a700e308c50f6a69c83d337/scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
# ...

# %%
from scipy import stats

# %%
ages
# Out:
# [12, 13, 45, 62, 7, 8, 76, 56, 4, 34, 6, 17, 17, 5, 4, 3, 45, 16]

# %%
stats.mode(ages)
# Out:
# ModeResult(mode=4, count=2)
