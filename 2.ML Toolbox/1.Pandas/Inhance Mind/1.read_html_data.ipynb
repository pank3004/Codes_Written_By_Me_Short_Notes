# %%
import pandas as pd

# %%
pip install lxml
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB 435.7 kB/s eta 0:00:09
#     --------------------------------------- 0.1/3.9 MB 363.1 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/3.9 MB 595.3 kB/s eta 0:00:07
#    - -------------------------------------- 0.2/3.9 MB 701.4 kB/s eta 0:00:06
#    - -------------------------------------- 0.2/3.9 MB 737.3 kB/s eta 0:00:06
#    -- ------------------------------------- 0.2/3.9 MB 793.0 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.9 MB 793.0 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.9 MB 793.0 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.9 MB 793.0 kB/s eta 0:00:05
# ...

# %%
data=pd.read_html("http://esdcdoi.esac.esa.int/doi/html/data/astronomy/xmm-newton/080195.html")

# %%
len(data)
# Out:
# 1

# %%
type(data)
# Out:
# list

# %%
df=data[0]

# %%
df
# Out:
#                            0  \
# 0                       Name
# 1                      Title
# 2                        URL
# 3                        DOI
# 4                     Author
# 5                Description
# 6                Publication
# 7                 Instrument
# 8          Temporal Coverage
# 9                    Version
# 10       Mission Description
# 11           Creator Contact
# 12            Date Published
# 13  Publisher And Registrant
# 14         Credit Guidelines
#
#                                                     1
# 0                                              080195
# 1   A Definitive Test for Evolution in the Metalli...
# 2   https://nxsa.esac.esa.int/nxsa-sl/servlet/data...
# 3                 https://doi.org/10.5270/esa-pfko9rx
# 4                                       Dr Adam Mantz
# 5   We propose deep observations of two massive ga...
# 6   No observations found associated with the curr...
# ...

# %%
df[[0,1]]
# Out:
#                            0  \
# 0                       Name
# 1                      Title
# 2                        URL
# 3                        DOI
# 4                     Author
# 5                Description
# 6                Publication
# 7                 Instrument
# 8          Temporal Coverage
# 9                    Version
# 10       Mission Description
# 11           Creator Contact
# 12            Date Published
# 13  Publisher And Registrant
# 14         Credit Guidelines
#
#                                                     1
# 0                                              080195
# 1   A Definitive Test for Evolution in the Metalli...
# 2   https://nxsa.esac.esa.int/nxsa-sl/servlet/data...
# 3                 https://doi.org/10.5270/esa-pfko9rx
# 4                                       Dr Adam Mantz
# 5   We propose deep observations of two massive ga...
# 6   No observations found associated with the curr...
# ...

# %%
df.to_csv("random_data.csv",index=False,header=False) # index is used to remove or add index
                                                      # header is used to remove or add column name
